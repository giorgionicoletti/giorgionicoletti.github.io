# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
import glob
import getorg
from geopy import Nominatim
import folium
# Out:
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipywidgets'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet

# %%
g = glob.glob("*.md")

# %%
data_talks = []
for file in g:
    talk_dict = {}
    with open(file, 'r') as f:
        lines = f.read()
        
        if lines.find('location: "') > 1:
            loc_start = lines.find('location: "') + 11
            lines_trim = lines[loc_start:]
            loc_end = lines_trim.find('"')
            location = lines_trim[:loc_end]

            title_start = lines.find('title: "') + 8 #look for title
            title_trim = lines[title_start:]
            title_end = title_trim.find('"')
            title = title_trim[:title_end]
            
            venue_start = lines.find('venue: "') + 8 #look for venue
            venue_trim = lines[venue_start:]
            venue_end = venue_trim.find('"')
            venue_name = venue_trim[:venue_end]

            period_start = lines.find('date: ') + 6 #look for period
            period_trim = lines[period_start:]
            period_end = period_trim.find('\n')
            period = period_trim[:period_end]

            type_start = lines.find('type: "') + 7 #look for type
            type_trim = lines[type_start:]
            type_end = type_trim.find('\n')
            type = type_trim[:type_end -1]

            #get the name of the file
            link = "https://giorgionicoletti.github.io/talks/" + file[:-3]

            talk_dict['title'] = title
            talk_dict['location'] = location
            talk_dict['venue'] = venue_name
            talk_dict['date'] = period
            talk_dict['type'] = type
            talk_dict['link'] = link
            
            data_talks.append(talk_dict)

# %%
from geopy.extra.rate_limiter import RateLimiter

geocoder = Nominatim(user_agent="gn_website")
geocode = RateLimiter(geocoder.geocode, min_delay_seconds=2, max_retries=3, error_wait_seconds=10)


from geopy.exc import GeocoderUnavailable, GeocoderTimedOut

for talk in data_talks:
    if talk['location'] == "Online":
        talk['lat'] = None
        talk['lon'] = None
        continue
    print(talk['location'])
    if "lat" in talk and "lon" in talk and talk["lat"] is not None and talk["lon"] is not None:
        continue  # Skip geocoding if lat and lon are already set
    try:
        location = geocode(talk['location'])
        if location:
            talk['lat'] = location.latitude
            talk['lon'] = location.longitude
        else:
            talk['lat'] = None
            talk['lon'] = None
    except (GeocoderUnavailable, GeocoderTimedOut) as e:
        print(f"Geocoding failed for {talk['location']}: {e}")
        talk['lat'] = None
        talk['lon'] = None
# Out:
# Berlin, Germany
# Florence, Italy
# Padova, Italy
# Trieste, Italy
# Dresden, Germany
# Lausanne, Switzerland
# Lyon, France
# Palma de Mallorca, Spain
# Dresden, Germany
# L'Aquila, Italy
# Tokyo, Japan
# Urbana-Champaign, USA
# Beg Rohu, France
# Lyon, France
# Tokyo, Japan
# Lyon, France
# Stockholm, Sweden
# Trieste, Italy
# Venice, Italy
# Padova, Italy
# Berlin, Germany
# Palma de Mallorca, Spain
# Tokyo, Japan
# Trento, Italy
# Santa Barbara, USA
# Naples, Italy
# Bethesda, USA

# %%
data_talks[8]
# Out:
# {'title': 'Unfolding complex systems with information theory',
#  'location': 'Online',
#  'venue': 'SIFS',
#  'date': '2022-03-10',
#  'type': 'Invited talk',
#  'link': 'https://giorgionicoletti.github.io/talks/2022-talk-SIFS-info',
#  'lat': None,
#  'lon': None}

# %%
data_talks[10]
# Out:
# {'title': 'Information theory in stochastic processes and complex systems',
#  'location': 'Dresden, Germany',
#  'venue': 'Max Planck Institute for the Physics of Complex Systems',
#  'date': '2022-07-13',
#  'type': 'Invited talk',
#  'link': 'https://giorgionicoletti.github.io/talks/2022-talk-MPIPKS',
#  'lat': 51.0493286,
#  'lon': 13.7381437}

# %%
def convert_date(date):
    date = date.split('-')
    month = date[1]
    day = date[2]
    year = date[0]
    if month == '01':
        month = 'January'
    elif month == '02':
        month = 'February'
    elif month == '03':
        month = 'March'
    elif month == '04':
        month = 'April'
    elif month == '05':
        month = 'May'
    elif month == '06':
        month = 'June'
    elif month == '07':
        month = 'July'
    elif month == '08':
        month = 'August'
    elif month == '09':
        month = 'September'
    elif month == '10':
        month = 'October'
    elif month == '11':
        month = 'November'
    elif month == '12':
        month = 'December'
    
    if day.endswith('1') and day != '11':
        day += 'st'
    elif day.endswith('2') and day != '12':
        day += 'nd'
    elif day.endswith('3') and day != '13':
        day += 'rd'
    else:
        day += 'th'

    # if days starts with 0, remove it
    if day.startswith('0'):
        day = day[1:]
    
    return month + ' ' + day + ', ' + year

# %%
for talk in data_talks:
    talk['venue'] = talk['venue'].replace('CCS', 'Conference on Complex Systems')

# %%
# remove Online talks
data_talks = [talk for talk in data_talks if talk['location'] != 'Online']

# %%
# merge the talks that took place in the same location
talks_merged = []

unique_locations = list(set([talk['location'] for talk in data_talks]))

for location in unique_locations:
    location_talks = [talk for talk in data_talks if talk['location'] == location]
    if len(location_talks) == 1:
        talk = location_talks[0]
        text = '<p style="font-size:1.3em; font-family: Avenir"><b>' + talk['venue'] + "</b>, "
        text += talk["location"]+"<br /><i>" + talk['title']
        text += "</i><br />" + convert_date(talk['date']) + " (" + talk['type'].lower() + ")</p>"
        talks_merged.append({'text': text, 'lat': talk['lat'], 'lon': talk['lon'], 'type': talk['type'], 'type': location_talks[0]['type'], 'num': None})
    else:
        text = '<p style="font-size:1.3em; font-family: Avenir">'

        types = []
        # sort location talks by date
        location_talks = sorted(location_talks, key=lambda x: x['date'], reverse=True)
        for talk in location_talks:
            text += '<b>' + talk['venue'] + "</b>, "
            text += talk["location"]+"<br /><i>" + talk['title']
            text += "</i><br />" + convert_date(talk['date']) + " (" + talk['type'].lower() + ")<br /><br />"
            
            if talk['type'] not in types:
                types.append(talk['type'])

        if "Invited talk" in types:
            type = "Invited talk"
        elif "Contributed talk" in types:
            type = "Contributed talk"
        elif "Contributed poster" in types:
            type = "Contributed poster"
    
        text += "</p>"
        talks_merged.append({'text': text, 'lat': location_talks[0]['lat'], 'lon': location_talks[0]['lon'], 'type': type, 'num': len(location_talks)})

# %%
talks_merged
# Out:
# [{'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Stochastic Models and Experiments in Ecology and Biology 2024</b>, L\'Aquila, Italy<br /><i>Spatially disordered environments stabilize competitive metacommunities</i><br />May 29th, 2024 (contributed talk)</p>',
#   'lat': 42.1368853,
#   'lon': 13.610341,
#   'type': 'Contributed talk',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Institute of Industrial Sciences, University of Tokyo</b>, Tokyo, Japan<br /><i>Information processing in multiscale biological systems: from transduction mechanisms to decision-making processes</i><br />March 27th, 2026 (invited talk)<br /><br /><b>From Biological Complexity to Evolutionary Principles (EPIC Assembly Symposium 2026)</b>, Tokyo, Japan<br /><i>Processing information from partially observed signals in biological systems with energetic constraints</i><br />March 15th, 2026 (contributed poster)<br /><br /><b>Statphys28</b>, Tokyo, Japan<br /><i>The architecture of information processing in biological systems</i><br />August 10th, 2023 (contributed talk)<br /><br /></p>',
#   'lat': 35.6768601,
#   'lon': 139.7638947,
#   'type': 'Invited talk',
#   'num': 3},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Conference on Complex Systems 2022</b>, Palma de Mallorca, Spain<br /><i>Information-driven transitions in optimal projections of underdamped dynamics</i><br />October 18th, 2022 (contributed talk)<br /><br /><b>Conference on Complex Systems 2022</b>, Palma de Mallorca, Spain<br /><i>Criticality and network structure drive emergent oscillations in a stochastic whole-brain model</i><br />October 17th, 2022 (contributed talk)<br /><br /></p>',
#   'lat': 39.5695818,
#   'lon': 2.6500745,
#   'type': 'Contributed talk',
#   'num': 2},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Brain Criticality Meeting 2022 (online)</b>, Bethesda, USA<br /><i>Criticality and network structure drive emergent oscillations in a stochastic whole-brain model</i><br />November 8th, 2022 (contributed poster)</p>',
#   'lat': 38.9812726,
#   'lon': -77.1233587,
#   'type': 'Contributed poster',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>ENAC Research Day 2024</b>, Lausanne, Switzerland<br /><i>Landscape and habitat heterogeneity drive niche coexistence in dispersing ecological metacommunities</i><br />September 9th, 2024 (contributed poster)</p>',
#   'lat': 46.5218269,
#   'lon': 6.6327025,
#   'type': 'Contributed poster',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Quantitative Life Sciences section, ICTP</b>, Trieste, Italy<br /><i>Information propagation across timescales</i><br />April 4th, 2024 (invited talk)<br /><br /><b>Information processing and decision-making in biology, ICTP</b>, Trieste, Italy<br /><i>Tuning transduction from hidden observables to optimize information harvesting</i><br />March 11th, 2024 (invited talk)<br /><br /></p>',
#   'lat': 45.6496485,
#   'lon': 13.7772781,
#   'type': 'Invited talk',
#   'num': 2},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Padova Neuroscience Center</b>, Padova, Italy<br /><i>Decoding behavior: inference of decision-making processes with interpretable agent models</i><br />November 14th, 2025 (invited talk)<br /><br /><b>\'Emergent dynamical patterns of disordered systems with applications to natural communities\' workshop, University of Padova</b>, Padova, Italy<br /><i>Survival and coexistence in spatially explicit metapopulation models</i><br />December 18th, 2023 (invited talk)<br /><br /></p>',
#   'lat': 45.391408,
#   'lon': 11.8058487,
#   'type': 'Invited talk',
#   'num': 2},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Information processing, noise and adaptation in living systems (SIGNAL24)</b>, Dresden, Germany<br /><i>Information propagation across timescales in multiscale systems</i><br />April 17th, 2024 (contributed talk)<br /><br /><b>Max Planck Institute for the Physics of Complex Systems</b>, Dresden, Germany<br /><i>Information theory in stochastic processes and complex systems</i><br />July 13th, 2022 (invited talk)<br /><br /></p>',
#   'lat': 51.0493286,
#   'lon': 13.7381437,
#   'type': 'Invited talk',
#   'num': 2},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>International Physics of Living Systems (iPoLS) Annual Meeting</b>, Urbana-Champaign, USA<br /><i>Optimizing transduction of information from hidden observables in biological systems with a limited energy budget</i><br />July 28th, 2025 (contributed talk)</p>',
#   'lat': 40.1108492,
#   'lon': -88.1619741,
#   'type': 'Contributed talk',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>BrainNet workshop, KTH</b>, Stockholm, Sweden<br /><i>What can criticality and phase transitions teach us about brain dynamics?</i><br />May 24th, 2022 (invited talk)</p>',
#   'lat': 59.3251172,
#   'lon': 18.0710935,
#   'type': 'Invited talk',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Neurophysics of Active Sensing, KITP</b>, Santa Barbara, USA<br /><i>Inference of decision-making strategies with finite memory states</i><br />August 13th, 2025 (contributed talk)</p>',
#   'lat': 34.4221319,
#   'lon': -119.702667,
#   'type': 'Contributed talk',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>The Beg Rohu Summer School 2021</b>, Beg Rohu, France<br /><i>On the critical signatures of neural activity</i><br />June 3rd, 2021 (contributed poster)</p>',
#   'lat': 47.509905,
#   'lon': -3.1180916,
#   'type': 'Contributed poster',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>First Italian Conference on Complex Systems</b>, Trento, Italy<br /><i>Scaling and Renormalization Group for the activity of neurons</i><br />July 2nd, 2019 (contributed poster)</p>',
#   'lat': 46.1029536,
#   'lon': 11.1297425,
#   'type': 'Contributed poster',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Bernstein Conference 2022</b>, Berlin, Germany<br /><i>Disentangling the critical signatures of neural activity: avalanches, spatial correlations and information</i><br />September 15th, 2022 (contributed poster)<br /><br /><b>Bernstein Conference 2020 (online)</b>, Berlin, Germany<br /><i>Scaling and criticality in a phenomenological Renormalization Group</i><br />October 1st, 2020 (contributed poster)<br /><br /></p>',
#   'lat': 52.5173885,
#   'lon': 13.3951309,
#   'type': 'Contributed poster',
#   'num': 2},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Statphys29</b>, Florence, Italy<br /><i>Tuning transduction from hidden observables to optimize information harvesting with a limited energy budget</i><br />July 14th, 2025 (contributed talk)</p>',
#   'lat': 43.7697955,
#   'lon': 11.2556404,
#   'type': 'Contributed talk',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Conference on Complex Systems 2021</b>, Lyon, France<br /><i>Modeling the emergence of scale-free fire outbreaks in Australia</i><br />October 26th, 2021 (contributed talk)<br /><br /><b>Conference on Complex Systems 2021</b>, Lyon, France<br /><i>Disentangling internal interactions from noisy environments through mutual information</i><br />October 26th, 2021 (contributed poster)<br /><br /><b>Conference on Complex Systems 2021</b>, Lyon, France<br /><i>Disentangling the role of external and intrinsic dynamics on the critical signatures of neural activity</i><br />October 25th, 2021 (contributed talk)<br /><br /></p>',
#   'lat': 45.7578137,
#   'lon': 4.8320114,
#   'type': 'Contributed talk',
#   'num': 3},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Stochastic Models and Experiments in Ecology and Biology 2021</b>, Venice, Italy<br /><i>Modeling the emergence of scale-free fire out-breaks in Australia</i><br />June 23rd, 2021 (contributed poster)</p>',
#   'lat': 45.4046171,
#   'lon': 12.3105232,
#   'type': 'Contributed poster',
#   'num': None},
#  {'text': '<p style="font-size:1.3em; font-family: Avenir"><b>Italian Conference on Complex Systems 2023</b>, Naples, Italy<br /><i>Emergent encoding of dispersal network topologies in spatial metapopulation models</i><br />October 9th, 2023 (contributed poster)</p>',
#   'lat': 40.8358846,
#   'lon': 14.2487679,
#   'type': 'Contributed poster',
#   'num': None}]

# %%
n = folium.Map(location=[40,40], tiles="cartodb positron", zoom_start=3, z_index = 0)

folium.map.CustomPane("Invited talk", z_index=1000).add_to(n)
folium.map.CustomPane("Contributed talk", z_index=999).add_to(n)
folium.map.CustomPane("Contributed poster", z_index=998).add_to(n)

folium.map.CustomPane("arrow", z_index=450).add_to(n)
# sort data talks in such a way that posters are at the beginning, contributed talks in the middle, and invited talks at the end

talks_merged = sorted(talks_merged, key=lambda x: x['type'])

for idx, talk in enumerate(talks_merged):
    # iframe = folium.IFrame('<p style="font-family: Avenir"><b>' + talk['venue'] + "</b>, "+talk["location"]+"<br /><i>" + talk['title'] + "</i><br />" + convert_date(talk['date']) + " (" +
    #                        talk['type'].lower() + ")</p>", width=500, height=150)
    #html = '<p style="font-size:1.3em; font-family: Avenir"><b>' + talk['venue'] + "</b>, "+ talk["location"]+"<br /><i>" + talk['title'] + "</i><br />" + convert_date(talk['date']) + " (" + talk['type'].lower() + ")</p>"
    
    popup = folium.Popup(talk['text'], min_width=200, max_width=300, max_height=150, min_height=100)

    if talk['type'] == 'Invited talk':
        color = 'darkred'

    elif talk['type'] == 'Contributed talk':
        color = 'darkblue'

    elif talk['type'] == 'Contributed poster':
        color = 'darkblue'

    folium.Marker(location = [talk['lat'], talk['lon']], popup=popup, marker_size = 100,
                  icon=folium.Icon(color=color, prefix = "fa")).add_to(n)

n
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4ba54c430d0f848021cabf2eb4a6a315 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4ba54c430d0f848021cabf2eb4a6a315&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4ba54c430d0f848021cabf2eb4a6a315 = L.map(
#                 &quot;map_4ba54c430d0f848021cabf2eb4a6a315&quot;,
#                 {
#                     center: [40.0, 40.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 3,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;zIndex&quot;: 0,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_172fa835ec1560a8516416cadf46c599 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_172fa835ec1560a8516416cadf46c599.addTo(map_4ba54c430d0f848021cabf2eb4a6a315);
#
#
#             var pane_7767d7d5998fbbc78828b58d864193bf = map_4ba54c430d0f848021cabf2eb4a6a315.createPane(
#                 &quot;Invited talk&quot;);
#             pane_7767d7d5998fbbc78828b58d864193bf.style.zIndex = 1000;
#
#                 pane_7767d7d5998fbbc78828b58d864193bf.style.pointerEvents = &#x27;none&#x27;;
#
#
#
#             var pane_07f8d635af8f9eaeff5cd9ca0b6cd679 = map_4ba54c430d0f848021cabf2eb4a6a315.createPane(
#                 &quot;Contributed talk&quot;);
#             pane_07f8d635af8f9eaeff5cd9ca0b6cd679.style.zIndex = 999;
#
#                 pane_07f8d635af8f9eaeff5cd9ca0b6cd679.style.pointerEvents = &#x27;none&#x27;;
#
#
#
#             var pane_fb2e631d19e0b1bea698962d5303e908 = map_4ba54c430d0f848021cabf2eb4a6a315.createPane(
#                 &quot;Contributed poster&quot;);
#             pane_fb2e631d19e0b1bea698962d5303e908.style.zIndex = 998;
#
#                 pane_fb2e631d19e0b1bea698962d5303e908.style.pointerEvents = &#x27;none&#x27;;
#
#
#
#             var pane_44b022ba5511ae55c181a836cb5dfe1a = map_4ba54c430d0f848021cabf2eb4a6a315.createPane(
#                 &quot;arrow&quot;);
#             pane_44b022ba5511ae55c181a836cb5dfe1a.style.zIndex = 450;
#
#                 pane_44b022ba5511ae55c181a836cb5dfe1a.style.pointerEvents = &#x27;none&#x27;;
#
#
#
#             var marker_c90d8c22c8d91ad0fa6dec1de63f69e3 = L.marker(
#                 [38.9812726, -77.1233587],
#                 {
#   &quot;markerSize&quot;: 100,
# }
#             ).addTo(map_4ba54c430d0f848021cabf2eb4a6a315);
#
#
#             var icon_7d85f32edd819a51b361d535fd3627c5 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_639f59a7d2c7d554b56ba6555647ad29 = L.popup({
#   &quot;maxWidth&quot;: 300,
#   &quot;minWidth&quot;: 200,
#   &quot;maxHeight&quot;: 150,
#   &quot;minHeight&quot;: 100,
# });
#
#
#
#                 var html_0103a18d6e607e766e88b9a7fd886ad5 = $(`&lt;div id=&quot;html_0103a18d6e607e766e88b9a7fd886ad5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;p style=&quot;font-size:1.3em; font-family: Avenir&quot;&gt;&lt;b&gt;Brain Criticality Meeting 2022 (online)&lt;/b&gt;, Bethesda, USA&lt;br /&gt;&lt;i&gt;Criticality and network structure drive emergent oscillations in a stochastic whole-brain model&lt;/i&gt;&lt;br /&gt;November 8th, 2022 (contributed poster)&lt;/p&gt;&lt;/div&gt;`)[0];
#                 popup_639f59a7d2c7d554b56ba6555647ad29.setContent(html_0103a18d6e607e766e88b9a7fd886ad5);
#
#
#
#         marker_c90d8c22c8d91ad0fa6dec1de63f69e3.bindPopup(popup_639f59a7d2c7d554b56ba6555647ad29)
#         ;
#
#
#
#
#                 marker_c90d8c22c8d91ad0fa6dec1de63f69e3.setIcon(icon_7d85f32edd819a51b361d535fd3627c5);
#
#
#             var marker_e3a9083a8056541f64e5d99bbe4fd75e = L.marker(
#                 [46.5218269, 6.6327025],
#                 {
#   &quot;markerSize&quot;: 100,
# }
#             ).addTo(map_4ba54c430d0f848021cabf2eb4a6a315);
#
#
#             var icon_1e905a7076479b5f9219f4093707f1ac = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;darkblue&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;fa&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6999b7a51fcf7b817ede75558c826b03 = L.p

# %%
# get the minimum and maximum latitude and longitude
min_lat = min([talk['lat'] for talk in data_talks if talk['lat'] is not None])
max_lat = max([talk['lat'] for talk in data_talks if talk['lat'] is not None])

min_lon = min([talk['lon'] for talk in data_talks if talk['lon'] is not None])
max_lon = max([talk['lon'] for talk in data_talks if talk['lon'] is not None])

n.fit_bounds([[min_lat, min_lon], [max_lat, max_lon]])

# %%
# save the map in html

n.save('../talkmap/talks_map.html')
