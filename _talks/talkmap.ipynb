# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
import glob
import getorg
from geopy import Nominatim
import folium

# %%
g = glob.glob("*.md")

# %%
data_talks = []
for file in g:
    talk_dict = {}
    with open(file, 'r') as f:
        lines = f.read()
        
        if lines.find('location: "') > 1:
            loc_start = lines.find('location: "') + 11
            lines_trim = lines[loc_start:]
            loc_end = lines_trim.find('"')
            location = lines_trim[:loc_end]

            title_start = lines.find('title: "') + 8 #look for title
            title_trim = lines[title_start:]
            title_end = title_trim.find('"')
            title = title_trim[:title_end]
            
            venue_start = lines.find('venue: "') + 8 #look for venue
            venue_trim = lines[venue_start:]
            venue_end = venue_trim.find('"')
            venue_name = venue_trim[:venue_end]

            period_start = lines.find('date: ') + 6 #look for period
            period_trim = lines[period_start:]
            period_end = period_trim.find('\n')
            period = period_trim[:period_end]

            type_start = lines.find('type: "') + 7 #look for type
            type_trim = lines[type_start:]
            type_end = type_trim.find('\n')
            type = type_trim[:type_end -1]

            #get the name of the file
            link = "https://giorgionicoletti.github.io/talks/" + file[:-3]

            talk_dict['title'] = title
            talk_dict['location'] = location
            talk_dict['venue'] = venue_name
            talk_dict['date'] = period
            talk_dict['type'] = type
            talk_dict['link'] = link
            
            data_talks.append(talk_dict)

# %%
geocoder = Nominatim(user_agent="gn_website")

for talk in data_talks:
    if talk['location'] == "Online":
        talk['lat'] = None
        talk['lon'] = None
        continue
    location = geocoder.geocode(talk['location'])
    if location:
        talk['lat'] = location.latitude
        talk['lon'] = location.longitude
    else:
        talk['lat'] = None
        talk['lon'] = None

# %%
data_talks[8]
# Out:
# {'title': 'Disentangling internal interactions from noisy environments through mutual information',
#  'location': 'Lyon, France',
#  'venue': 'CCS 2021',
#  'date': '2021-10-26',
#  'type': 'Contributed poster',
#  'link': 'https://giorgionicoletti.github.io/talks/2021-poster-CCS-mutual',
#  'lat': 45.7578137,
#  'lon': 4.8320114}

# %%
data_talks[10]
# Out:
# {'title': 'Disentangling the role of external and intrinsic dynamics on the critical signatures of neural activityd',
#  'location': 'Lyon, France',
#  'venue': 'CCS 2021',
#  'date': '2021-10-25',
#  'type': 'Contributed talk',
#  'link': 'https://giorgionicoletti.github.io/talks/2021-talk-CCS-avalanches',
#  'lat': 45.7578137,
#  'lon': 4.8320114}

# %%
n = folium.Map(location=[40,40], tiles="cartodb positron", zoom_start=3)

for talk in data_talks:
    if talk['lat'] is not None:
        iframe = folium.IFrame(talk['title'])
        popup = folium.Popup(iframe, min_width=300, max_width=300, max_height=100, min_height=100)

        folium.Marker(location = [talk['lat'], talk['lon']], popup=popup).add_to(n)

n
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_419afa0bfbb87421709c0325b6326fac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_419afa0bfbb87421709c0325b6326fac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_419afa0bfbb87421709c0325b6326fac = L.map(
#                 &quot;map_419afa0bfbb87421709c0325b6326fac&quot;,
#                 {
#                     center: [40.0, 40.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_40b2847084d9a22ce30b90b8897ccea5 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_40b2847084d9a22ce30b90b8897ccea5.addTo(map_419afa0bfbb87421709c0325b6326fac);
#
#
#             var marker_37acf1c18ba2be0cd9adc7de17aea705 = L.marker(
#                 [52.5170365, 13.3888599],
#                 {}
#             ).addTo(map_419afa0bfbb87421709c0325b6326fac);
#
#
#         var popup_89870eb11b25ca7dc685f090055fbce5 = L.popup({&quot;maxHeight&quot;: 100, &quot;maxWidth&quot;: 300, &quot;minHeight&quot;: 100, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_2871166fad6f2e9a6e4fc588b7b0482b = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBTY2FsaW5nIGFuZCBjcml0aWNhbGl0eSBpbiBhIHBoZW5vbWVub2xvZ2ljYWwgUmVub3JtYWxpemF0aW9uIEdyb3Vw&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_89870eb11b25ca7dc685f090055fbce5.setContent(i_frame_2871166fad6f2e9a6e4fc588b7b0482b);
#
#
#
#         marker_37acf1c18ba2be0cd9adc7de17aea705.bindPopup(popup_89870eb11b25ca7dc685f090055fbce5)
#         ;
#
#
#
#
#             var marker_c7428109ad46d2b3db04cb053990b982 = L.marker(
#                 [45.4077172, 11.8734455],
#                 {}
#             ).addTo(map_419afa0bfbb87421709c0325b6326fac);
#
#
#         var popup_971006624b2be57105a2ab294dacc72d = L.popup({&quot;maxHeight&quot;: 100, &quot;maxWidth&quot;: 300, &quot;minHeight&quot;: 100, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_be976f22d7ecc861ea17d82f65c11446 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBTdXJ2aXZhbCBhbmQgY29leGlzdGVuY2UgaW4gc3BhdGlhbGx5IGV4cGxpY2l0IG1ldGFwb3B1bGF0aW9uIG1vZGVscw==&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_971006624b2be57105a2ab294dacc72d.setContent(i_frame_be976f22d7ecc861ea17d82f65c11446);
#
#
#
#         marker_c7428109ad46d2b3db04cb053990b982.bindPopup(popup_971006624b2be57105a2ab294dacc72d)
#         ;
#
#
#
#
#             var marker_f8ecee646c7c8a3beeca2906474a4652 = L.marker(
#                 [45.7578137, 4.8320114],
#                 {}
#             ).addTo(map_419afa0bfbb87421709c0325b6326fac);
#
#
#         var popup_45e76ffaed61e9c90b1968f43bfe99af = L.popup({&quot;maxHeight&quot;: 100, &quot;maxWidth&quot;: 300, &quot;minHeight&quot;: 100, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_4c3722a684be4e8da6adb76a8fa58ef0 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:60%;&quot;&gt;&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBNb2RlbGluZyB0aGUgZW1lcmdlbmNlIG9mIHNjYWxlLWZyZWUgZmlyZSBvdXRicmVha3MgaW4gQXVzdHJhbGlh&quot; style=&quot;position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;&quot;&gt;&lt;/iframe&gt;&lt;/div&gt;&lt;/div&gt;`)[0];
#                 popup_45e76ffaed61e9c90b1968f43bfe99af.setContent(i_frame_4c3722a684be4e8da6adb76a8fa58ef0);
#
#
#
#         marker_f8ecee646c7c8a3beeca2906474a4652.bindPopup(popup_45e76ffaed61e9c90b1968f43bfe99af)
#         ;
#
#
#
#
#             var marker_0de21f196a4b57ff1a0d5753dac60593 = L.marker(
#                 [39.5695818, 2.6500745],
#                 {}
#             ).addTo(map_419afa0bfbb87421709c0325b6326fac);
#
#
#         var popup_7f651233c7e0fade0e4cd96658bbade4 = L.popup({&quot;maxHeight&quot;: 100, &quot;maxWidth&quot;: 300, &quot;minHeight&quot;: 100, &quot;minWidth&quot;: 300});
#
#
#
#                 var i_frame_899a752b5b64b677b6aa7d856eaaafb0 = $(`&lt;div style=&quot;width:100%;&quot;&gt;&lt;div style=&quot;position:relative;width:100%;height:0;padding-bottom:

# %%
m = getorg.orgmap.create_map_obj()
getorg.orgmap.output_html_cluster_map(location_dict, folder_name="../talkmap", hashed_usernames=False)
# Out:
# 'Written map to ../talkmap/'

# %%
import folium

# %%
folium.Marker
# Out:
# folium.map.Marker

# %%
location_dict['Padova, Italy'].longitude
# Out:
# 11.8734455

# %%
n = folium.Map(location=[40,40], tiles="cartodb positron", zoom_start=3)

for key, value in location_dict.items():
    if value is not None:
        folium.Marker(location = [value.latitude, value.longitude], popup=key).add_to(n)

n
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_43d90f3230798492c16a493033223b07 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_43d90f3230798492c16a493033223b07&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_43d90f3230798492c16a493033223b07 = L.map(
#                 &quot;map_43d90f3230798492c16a493033223b07&quot;,
#                 {
#                     center: [40.0, 40.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c437c94febc5c53150d2bc1d219a2882 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c437c94febc5c53150d2bc1d219a2882.addTo(map_43d90f3230798492c16a493033223b07);
#
#
#             var marker_2b99ea47044c2b2dafcd7774c0db76c2 = L.marker(
#                 [45.4077172, 11.8734455],
#                 {}
#             ).addTo(map_43d90f3230798492c16a493033223b07);
#
#
#         var popup_4a101b8908299ce451d3d0d1ef94a7e9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ec2c05fc5cbc8a635100fcff58763cfe = $(`&lt;div id=&quot;html_ec2c05fc5cbc8a635100fcff58763cfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Padova, Italy&lt;/div&gt;`)[0];
#                 popup_4a101b8908299ce451d3d0d1ef94a7e9.setContent(html_ec2c05fc5cbc8a635100fcff58763cfe);
#
#
#
#         marker_2b99ea47044c2b2dafcd7774c0db76c2.bindPopup(popup_4a101b8908299ce451d3d0d1ef94a7e9)
#         ;
#
#
#
#
#             var marker_e5f42bc780c876b10ea3aa2aeddd595c = L.marker(
#                 [45.7578137, 4.8320114],
#                 {}
#             ).addTo(map_43d90f3230798492c16a493033223b07);
#
#
#         var popup_6f7fc22b2c10a15c1c7619c9edfd0569 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_abfcb558867a8c5041846a1b9a3498b5 = $(`&lt;div id=&quot;html_abfcb558867a8c5041846a1b9a3498b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Lyon, France&lt;/div&gt;`)[0];
#                 popup_6f7fc22b2c10a15c1c7619c9edfd0569.setContent(html_abfcb558867a8c5041846a1b9a3498b5);
#
#
#
#         marker_e5f42bc780c876b10ea3aa2aeddd595c.bindPopup(popup_6f7fc22b2c10a15c1c7619c9edfd0569)
#         ;
#
#
#
#
#             var marker_7b240e51cfdb4171f265960b6d6e4489 = L.marker(
#                 [39.5695818, 2.6500745],
#                 {}
#             ).addTo(map_43d90f3230798492c16a493033223b07);
#
#
#         var popup_32fbbc51d5133a93e0aa73e2faac5cdb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_936ec8500e16255c765dc9c201140486 = $(`&lt;div id=&quot;html_936ec8500e16255c765dc9c201140486&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Palma de Mallorca, Spain&lt;/div&gt;`)[0];
#                 popup_32fbbc51d5133a93e0aa73e2faac5cdb.setContent(html_936ec8500e16255c765dc9c201140486);
#
#
#
#         marker_7b240e51cfdb4171f265960b6d6e4489.bindPopup(popup_32fbbc51d5133a93e0aa73e2faac5cdb)
#         ;
#
#
#
#
#             var marker_bad85ce714d3a82adfb2912a31de4ac0 = L.marker(
#                 [51.0493286, 13.7381437],
#                 {}
#             ).addTo(map_43d90f3230798492c16a493033223b07);
#
#
#         var popup_a36c2256e9c4b5cb83c0826f7d80e116 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_202ef539c8754277de914d635601d510 = $(`&lt;div id=&quot;html_202ef539c8754277de914d635601d510&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Dresden, Germany&lt;/div&gt;`)[0];
#                 popup_a36c2256e9c4b5cb83c0826f7d80e116.setContent(html_202ef539c8754277de914d635601d510);
#
#
#
#         marker_bad85ce714d3a82adfb2912a31de4ac0.bindPopup(popup_a36c2256e9c4b5cb83c0826f7d80e116)
#         ;
#
#
#
#
#             var marker_4fbc387ae10466e3cd95bbf19d3bc836 = L.marker(
#                 [47.509905, -3.1180916],
#                 {}
#             ).addTo(map_43d90f3230798492c16a493033223b07);
#
#
#         var popup_9b9ad8280ca680b4de9bc631d91a5ded = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2aefc739f7393f1f774ab754ae3ca7f5 = $(`&lt;div id=&quot;html_2aefc739f7393f1f774ab754ae3ca7f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Beg Rohu, France&lt;/div&gt;`)[0];
#                 popup_9b9ad8280ca680b4de9bc631d91a5ded.setContent(html_2aefc739f7393f1f774ab754ae3ca7f5);
#
#
#
#         marker_4fbc387ae10466e3cd95bbf19d3bc836.bindPopup(popup_9b9ad8280ca680b4de9bc631d91a5ded)
#         ;
#
#
#
#
#             var marker_bc2a629c2bb511232940d6860528bfc5 = L.marker(

# %%
# Make an empty map
n = folium.Map(location=[20,0], tiles="OpenStreetMap", zoom_start=2)

# add marker one by one on the map
for i in range(0,len(data)):
   folium.Marker(
      location=[data.iloc[i]['lat'], data.iloc[i]['lon']],
      popup=data.iloc[i]['name']
   ).add_to(n)

# Show the map again
n
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_816eaabe9aeb60f9d0e71edd8e9350c3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_816eaabe9aeb60f9d0e71edd8e9350c3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_816eaabe9aeb60f9d0e71edd8e9350c3 = L.map(
#                 &quot;map_816eaabe9aeb60f9d0e71edd8e9350c3&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 2,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_aa5ee249694b20f78dd64e90dde1dd9b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_aa5ee249694b20f78dd64e90dde1dd9b.addTo(map_816eaabe9aeb60f9d0e71edd8e9350c3);
#
#
#             var marker_28f8ebd6c7d0f2facf51adcb0ab399ea = L.marker(
#                 [-34.0, -58.0],
#                 {}
#             ).addTo(map_816eaabe9aeb60f9d0e71edd8e9350c3);
#
#
#         var popup_34ad25113a5d28976ee18539c6fbecdb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4a5473faf2ed33c8ee4980115ca4e01e = $(`&lt;div id=&quot;html_4a5473faf2ed33c8ee4980115ca4e01e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Buenos Aires&lt;/div&gt;`)[0];
#                 popup_34ad25113a5d28976ee18539c6fbecdb.setContent(html_4a5473faf2ed33c8ee4980115ca4e01e);
#
#
#
#         marker_28f8ebd6c7d0f2facf51adcb0ab399ea.bindPopup(popup_34ad25113a5d28976ee18539c6fbecdb)
#         ;
#
#
#
#
#             var marker_8aa1d5521d542056029084e62b634b80 = L.marker(
#                 [49.0, 2.0],
#                 {}
#             ).addTo(map_816eaabe9aeb60f9d0e71edd8e9350c3);
#
#
#         var popup_1f6888af17512cc6b88bc99a99cf82c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_bede1cb87ada6c98b6360df40bf99bca = $(`&lt;div id=&quot;html_bede1cb87ada6c98b6360df40bf99bca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Paris&lt;/div&gt;`)[0];
#                 popup_1f6888af17512cc6b88bc99a99cf82c7.setContent(html_bede1cb87ada6c98b6360df40bf99bca);
#
#
#
#         marker_8aa1d5521d542056029084e62b634b80.bindPopup(popup_1f6888af17512cc6b88bc99a99cf82c7)
#         ;
#
#
#
#
#             var marker_db40ec977cecc15713ab0009ca2de0b7 = L.marker(
#                 [-38.0, 145.0],
#                 {}
#             ).addTo(map_816eaabe9aeb60f9d0e71edd8e9350c3);
#
#
#         var popup_913f56b3be00c946053d0f00aefc725d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0dd6c234a6dd7ec473bd21a23a41c883 = $(`&lt;div id=&quot;html_0dd6c234a6dd7ec473bd21a23a41c883&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;melbourne&lt;/div&gt;`)[0];
#                 popup_913f56b3be00c946053d0f00aefc725d.setContent(html_0dd6c234a6dd7ec473bd21a23a41c883);
#
#
#
#         marker_db40ec977cecc15713ab0009ca2de0b7.bindPopup(popup_913f56b3be00c946053d0f00aefc725d)
#         ;
#
#
#
#
#             var marker_18fbc506a4c11f8a667cdb0784876d77 = L.marker(
#                 [59.93, 30.32],
#                 {}
#             ).addTo(map_816eaabe9aeb60f9d0e71edd8e9350c3);
#
#
#         var popup_71e1782baeec4f4c65d109684aafeb3e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_599a18db2852a8b040bda154f0961f77 = $(`&lt;div id=&quot;html_599a18db2852a8b040bda154f0961f77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;St Petersbourg&lt;/div&gt;`)[0];
#                 popup_71e1782baeec4f4c65d109684aafeb3e.setContent(html_599a18db2852a8b040bda154f0961f77);
#
#
#
#         marker_18fbc506a4c11f8a667cdb0784876d77.bindPopup(popup_71e1782baeec4f4c65d109684aafeb3e)
#         ;
#
#
#
#
#             var marker_06d0792a9a0514636a8be60e96a7b143 = L.marker(
#                 [5.33, -4.03],
#                 {}
#             ).addTo(map_816eaabe9aeb60f9d0e71edd8e9350c3);
#
#
#         var popup_f92d580126e34178f1bd365d41b55ac7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fac474344616c67f8cff2d1e1e0e641c = $(`&lt;div id=&quot;html_fac474344616c67f8cff2d1e1e0e641c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Abidjan&lt;/div&gt;`)[0];
#                 popup_f92d580126e34178f1bd365d41b55ac7.setContent(html_fac474344616c67f8cff2d1e1e0e641c);
#
#
#
#         marker_06d0792a9a0514636a8be60e96a7b143.bindPopup(popup_f92d580126e34178f1bd365d41b55ac7)
#         ;
#
#
#
#
#             var marker_51dc2a3fa7345dd65e76265478ef8cd6 = L.marker(
#                 [45.52, -73.57],
#                 {}
#             ).addTo(map_816eaabe9aeb60f9d0e71edd8e9350c3);
#
#
#         var popup_90535ec1c537800c6f14c07fe8d5b41b = L.popup({&quot;maxWi
