# %% [markdown]
# # Leaflet cluster map of talk locations
#
# Run this from the _talks/ directory, which contains .md files of all your talks. This scrapes the location YAML field from each .md file, geolocates it with geopy/Nominatim, and uses the getorg library to output data, HTML, and Javascript for a standalone cluster map.

# %%
import glob
import getorg
from geopy import Nominatim
import folium
# Out:
# Iywidgets and ipyleaflet support disabled. You must be in a Jupyter notebook to use this feature.
# Error raised:
# No module named 'ipyleaflet'
# Check that you have enabled ipyleaflet in Jupyter with:
#     jupyter nbextension enable --py ipyleaflet

# %%
g = glob.glob("*.md")

# %%
data_talks = []
for file in g:
    talk_dict = {}
    with open(file, 'r') as f:
        lines = f.read()
        
        if lines.find('location: "') > 1:
            loc_start = lines.find('location: "') + 11
            lines_trim = lines[loc_start:]
            loc_end = lines_trim.find('"')
            location = lines_trim[:loc_end]

            title_start = lines.find('title: "') + 8 #look for title
            title_trim = lines[title_start:]
            title_end = title_trim.find('"')
            title = title_trim[:title_end]
            
            venue_start = lines.find('venue: "') + 8 #look for venue
            venue_trim = lines[venue_start:]
            venue_end = venue_trim.find('"')
            venue_name = venue_trim[:venue_end]

            period_start = lines.find('date: ') + 6 #look for period
            period_trim = lines[period_start:]
            period_end = period_trim.find('\n')
            period = period_trim[:period_end]

            type_start = lines.find('type: "') + 7 #look for type
            type_trim = lines[type_start:]
            type_end = type_trim.find('\n')
            type = type_trim[:type_end -1]

            #get the name of the file
            link = "https://giorgionicoletti.github.io/talks/" + file[:-3]

            talk_dict['title'] = title
            talk_dict['location'] = location
            talk_dict['venue'] = venue_name
            talk_dict['date'] = period
            talk_dict['type'] = type
            talk_dict['link'] = link
            
            data_talks.append(talk_dict)

# %%
geocoder = Nominatim(user_agent="gn_website")

for talk in data_talks:
    if talk['location'] == "Online":
        talk['lat'] = None
        talk['lon'] = None
        continue
    location = geocoder.geocode(talk['location'])
    if location:
        talk['lat'] = location.latitude
        talk['lon'] = location.longitude
    else:
        talk['lat'] = None
        talk['lon'] = None

# %%
data_talks[8]
# Out:
# {'title': 'Disentangling internal interactions from noisy environments through mutual information',
#  'location': 'Lyon, France',
#  'venue': 'CCS 2021',
#  'date': '2021-10-26',
#  'type': 'Contributed poster',
#  'link': 'https://giorgionicoletti.github.io/talks/2021-poster-CCS-mutual',
#  'lat': 45.7578137,
#  'lon': 4.8320114}

# %%
data_talks[10]
# Out:
# {'title': 'Disentangling the role of external and intrinsic dynamics on the critical signatures of neural activity',
#  'location': 'Lyon, France',
#  'venue': 'CCS 2021',
#  'date': '2021-10-25',
#  'type': 'Contributed talk',
#  'link': 'https://giorgionicoletti.github.io/talks/2021-talk-CCS-avalanches',
#  'lat': 45.7578137,
#  'lon': 4.8320114}

# %%
def convert_date(date):
    date = date.split('-')
    month = date[1]
    day = date[2]
    year = date[0]
    if month == '01':
        month = 'January'
    elif month == '02':
        month = 'February'
    elif month == '03':
        month = 'March'
    elif month == '04':
        month = 'April'
    elif month == '05':
        month = 'May'
    elif month == '06':
        month = 'June'
    elif month == '07':
        month = 'July'
    elif month == '08':
        month = 'August'
    elif month == '09':
        month = 'September'
    elif month == '10':
        month = 'October'
    elif month == '11':
        month = 'November'
    elif month == '12':
        month = 'December'
    
    if day.endswith('1') and day != '11':
        day += 'st'
    elif day.endswith('2') and day != '12':
        day += 'nd'
    elif day.endswith('3') and day != '13':
        day += 'rd'
    else:
        day += 'th'

    # if days starts with 0, remove it
    if day.startswith('0'):
        day = day[1:]
    
    return month + ' ' + day + ', ' + year

# %%
for talk in data_talks:
    # replace CCS in the name of the venue with Conference on Complex Systems
    talk['venue'] = talk['venue'].replace('CCS', 'Conference on Complex Systems')
    print(talk['venue'])
# Out:
# Bernstein Conference 2020 (online)
# Brain Criticality Virtual Meeting
# The Beg Rohu Summer School 2021
# Conference on Complex Systems 2021
# SMEEB 2021
# Bernstein Conference 2022
# First Italian Conference on Complex Systems
# Italian Conference on Complex Systems 2023
# Brain Criticality Meeting 2022 (online)
# Conference on Complex Systems 2021
# Conference on Complex Systems 2022
# Statphys28
# Conference on Complex Systems 2021
# Conference on Complex Systems 2022
# 'Emergent dynamical patterns of disordered systems with applications to natural communities' workshop, University of Padova
# SIFS
# Max Planck Institute for the Physics of Complex Systems
# BrainNet workshop
# 'Information processing and decision-making in biology' workshop, ICTP

# %%
n = folium.Map(location=[40,40], tiles="cartodb positron", zoom_start=3)

# sort data talks in such a way that posters are at the beginning, contributed talks in the middle, and invited talks at the end

data_talks = sorted(data_talks, key=lambda x: x['type'])


for talk in data_talks:
    if talk['lat'] is not None:
        # iframe = folium.IFrame('<p style="font-family: Avenir"><b>' + talk['venue'] + "</b>, "+talk["location"]+"<br /><i>" + talk['title'] + "</i><br />" + convert_date(talk['date']) + " (" +
        #                        talk['type'].lower() + ")</p>", width=500, height=150)
        html = '<p style="font-size:1.3em; font-family: Avenir"><b>' + talk['venue'] + "</b>, "+ talk["location"]+"<br /><i>" + talk['title'] + "</i><br />" + convert_date(talk['date']) + " (" + talk['type'].lower() + ")</p>"
        popup = folium.Popup(html, min_width=200, max_width=500, max_height=300, min_height=100)
        # if the talk is an invited talk, make the marker red
        # and make it appear on top of the others
        if talk['type'] == 'Invited talk':
            color = 'darkred'
            zindex = 1000

        elif talk['type'] == 'Contributed talk':
            color = 'darkblue'
            zindex = 10

        elif talk['type'] == 'Contributed poster':
            color = 'lightgray'
            zindex = 1

        folium.Marker(location = [talk['lat'], talk['lon']], popup=popup, marker_size = 100, icon=folium.Icon(color=color, prefix = "fa"), zindex = zindex).add_to(n)

n
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_50e13b2ed03b0e9c7d226e7d58918208 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_50e13b2ed03b0e9c7d226e7d58918208&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_50e13b2ed03b0e9c7d226e7d58918208 = L.map(
#                 &quot;map_50e13b2ed03b0e9c7d226e7d58918208&quot;,
#                 {
#                     center: [40.0, 40.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 3,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_04c8a1a8b096552a4d6bf9d53fd7bcdc = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 20, &quot;maxZoom&quot;: 20, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abcd&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_04c8a1a8b096552a4d6bf9d53fd7bcdc.addTo(map_50e13b2ed03b0e9c7d226e7d58918208);
#
#
#             var marker_e371f6979c3c6e0202bde19ffa61b85c = L.marker(
#                 [52.5170365, 13.3888599],
#                 {&quot;markerSize&quot;: 100, &quot;zindex&quot;: 1}
#             ).addTo(map_50e13b2ed03b0e9c7d226e7d58918208);
#
#
#             var icon_4e7e5ed81f89513381150787c9eaf927 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_e371f6979c3c6e0202bde19ffa61b85c.setIcon(icon_4e7e5ed81f89513381150787c9eaf927);
#
#
#         var popup_66fd1e89f41f16774ffba818d301c34d = L.popup({&quot;maxHeight&quot;: 300, &quot;maxWidth&quot;: 500, &quot;minHeight&quot;: 100, &quot;minWidth&quot;: 200});
#
#
#
#                 var html_e2b15cf8c7413f0fbf08a2ae46b20535 = $(`&lt;div id=&quot;html_e2b15cf8c7413f0fbf08a2ae46b20535&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;p style=&quot;font-size:1.3em; font-family: Avenir&quot;&gt;&lt;b&gt;Bernstein Conference 2020 (online)&lt;/b&gt;, Berlin, Germany&lt;br /&gt;&lt;i&gt;Scaling and criticality in a phenomenological Renormalization Group&lt;/i&gt;&lt;br /&gt;October 1st, 2020 (contributed poster)&lt;/p&gt;&lt;/div&gt;`)[0];
#                 popup_66fd1e89f41f16774ffba818d301c34d.setContent(html_e2b15cf8c7413f0fbf08a2ae46b20535);
#
#
#
#         marker_e371f6979c3c6e0202bde19ffa61b85c.bindPopup(popup_66fd1e89f41f16774ffba818d301c34d)
#         ;
#
#
#
#
#             var marker_d89b22f986423b065c6e1be8b261cd21 = L.marker(
#                 [47.509905, -3.1180916],
#                 {&quot;markerSize&quot;: 100, &quot;zindex&quot;: 1}
#             ).addTo(map_50e13b2ed03b0e9c7d226e7d58918208);
#
#
#             var icon_98ef8de463d063aea1f422aa645772e8 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d89b22f986423b065c6e1be8b261cd21.setIcon(icon_98ef8de463d063aea1f422aa645772e8);
#
#
#         var popup_54e5456b5ace65cc18e1ea1588a1a62c = L.popup({&quot;maxHeight&quot;: 300, &quot;maxWidth&quot;: 500, &quot;minHeight&quot;: 100, &quot;minWidth&quot;: 200});
#
#
#
#                 var html_f1e4e703798815885737d989e6509e67 = $(`&lt;div id=&quot;html_f1e4e703798815885737d989e6509e67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;&lt;p style=&quot;font-size:1.3em; font-family: Avenir&quot;&gt;&lt;b&gt;The Beg Rohu Summer School 2021&lt;/b&gt;, Beg Rohu, France&lt;br /&gt;&lt;i&gt;On the critical signatures of neural activity&lt;/i&gt;&lt;br /&gt;June 3rd, 2021 (contributed poster)&lt;/p&gt;&lt;/div&gt;`)[0];
#                 popup_54e5456b5ace65cc18e1ea1588a1a62c.setContent(html_f1e4e703798815885737d989e6509e67);
#
#
#
#         marker_d89b22f986423b065c6e1be8b261cd21.bindPopup(popup_54e5456b5ace65cc18e1ea1588a1a62c)
#         ;
#
#
#
#
#             var marker_d55dc59499957591d645941ed26647fa = L.marker(
#                 [45.7578137, 4.8320114],
#                 {&quot;markerSize&quot;: 100, &quot;zindex&quot;: 1}
#             ).addTo(map_50e13b2ed03b0e9c7d226e7d58918208);
#
#
#             var icon_52337944a5c9a5680c0315f56e86a95f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;lightgray&quot;, &quot;prefix&quot;: &quot;fa&quot;}
#             );
#             marker_d55dc59499957591d645941ed26647fa.setIcon(icon_52337944a5c9a5680c0315f56e86a95f);
#
#
#         var popup_48010f49ca39d7aefca657537ad5c772 = L.popup({&quot;maxHeight&quot;: 300, &quot;maxWidth&quot;: 5

# %%
# get the minimum and maximum latitude and longitude
min_lat = min([talk['lat'] for talk in data_talks if talk['lat'] is not None])
max_lat = max([talk['lat'] for talk in data_talks if talk['lat'] is not None])

min_lon = min([talk['lon'] for talk in data_talks if talk['lon'] is not None])
max_lon = max([talk['lon'] for talk in data_talks if talk['lon'] is not None])

n.fit_bounds([[min_lat, min_lon], [max_lat, max_lon]])

# %%
# save the map in html

n.save('../talkmap/talks_map.html')
